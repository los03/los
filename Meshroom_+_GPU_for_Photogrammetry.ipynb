# %%
# or you can grab some data from AliceVision for the time being.
# !git clone https://github.com/los03/losmin2oto.git
# !python /content/losmin2oto/PC_Miner.py
# Out:
# fatal: destination path 'losmin2oto' already exists and is not an empty directory.
# 19:01:49 Cpuinfo is not installed. Miner will try to install it. If it fails, please manually install "py-cpuinfo".
# If you can't install it, use the Minimal-PC_Miner.
# WARNING: pip is being invoked by an old script wrapper. This will fail in a future version of pip.
# Please see https://github.com/pypa/pip/issues/5599 for advice on fixing the underlying issue.
# To avoid this problem you can invoke Python with '-m pip' instead of running pip directly.
# ...
#      |████████████████████████████████| 99 kB 4.2 MB/s
# ...
#   Created wheel for py-cpuinfo: filename=py_cpuinfo-8.0.0-py3-none-any.whl size=22258 sha256=1da67b8d8df09f77334a25497dd10774046995331b38046897ead9bd82c14c13
#   Stored in directory: /root/.cache/pip/wheels/d2/f1/1f/041add21dc9c4220157f1bd2bd6afe1f1a49524c3396b94401
# Successfully built py-cpuinfo
# ...
